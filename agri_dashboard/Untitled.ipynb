# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('agri_energy.csv')

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 79591    False
# 79592    False
# 79593    False
# 79594    False
# 79595    False
# Length: 79596, dtype: bool

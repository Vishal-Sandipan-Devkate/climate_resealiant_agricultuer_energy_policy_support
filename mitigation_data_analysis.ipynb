# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load dataset
agri_data = pd.read_csv('india_agriculture_renewable_energy.csv')
agri_data.head()
# Out:
#             State    District  Year  Month  Renewable_Capacity_MW  \
# 0         Haryana  District_7  2019      1             194.260217
# 1          Punjab  District_6  2016      6             422.496451
# 2      Tamil Nadu  District_6  2022      9            3606.331962
# 3  Madhya Pradesh  District_4  2025     11            2475.402768
# 4           Assam  District_4  2018      7              99.539133
#
#       Solar_MW     Wind_MW    Hydro_MW  Bioenergy_MW  \
# 0   104.148423   31.932236   11.162449      6.686043
# 1   204.494617  106.971434   50.500124     27.861010
# 2  1985.991170  965.553175  406.722131    122.103263
# 3  1457.291785  619.424790  335.787174    183.039850
# 4    53.541410   22.341401    8.994821      6.363836
#
#    Agriculture_Electricity_Use_GWh  Solar_Pumps_Installed  \
# 0                        90.792440                 3565.0
# 1                       109.135426                  875.0
# 2                              NaN                 2092.0
# ...

# %%
# Column Overview
agri_data.columns
# Out:
# Index(['State', 'District', 'Year', 'Month', 'Renewable_Capacity_MW',
#        'Solar_MW', 'Wind_MW', 'Hydro_MW', 'Bioenergy_MW',
#        'Agriculture_Electricity_Use_GWh', 'Solar_Pumps_Installed',
#        'Estimated_CO2_Reduction_tonnes'],
#       dtype='object')

# %%
# State Unique values overview
agri_data['State'].unique()
# Out:
# array(['Haryana', 'Punjab', 'Tamil Nadu', 'Madhya Pradesh', 'Assam',
#        'Gujarat', 'Bihar', 'Odisha', 'Maharashtra', 'Telangana',
#        'Andhra Pradesh', 'Chhattisgarh', 'Uttar Pradesh', 'Kerala',
#        'Karnataka', 'Rajasthan', 'West Bengal'], dtype=object)

# %%
# District Unique value overview
agri_data['District'].unique()
# Out:
# array(['District_7', 'District_6', 'District_4', 'District_8',
#        'District_1', 'District_2', 'District_5', 'District_3'],
#       dtype=object)

# %%
 # Columns data tyoe overview
agri_data.dtypes
# Out:
# State                               object
# District                            object
# Year                                 int64
# Month                                int64
# Renewable_Capacity_MW              float64
# Solar_MW                           float64
# Wind_MW                            float64
# Hydro_MW                           float64
# Bioenergy_MW                       float64
# Agriculture_Electricity_Use_GWh    float64
# Solar_Pumps_Installed              float64
# Estimated_CO2_Reduction_tonnes     float64
# dtype: object

# %%
#  Quick dataset overview
agri_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47952 entries, 0 to 47951
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   State                            47952 non-null  object
#  1   District                         47952 non-null  object
#  2   Year                             47952 non-null  int64
#  3   Month                            47952 non-null  int64
#  4   Renewable_Capacity_MW            45042 non-null  float64
#  5   Solar_MW                         44007 non-null  float64
#  6   Wind_MW                          44692 non-null  float64
#  7   Hydro_MW                         47952 non-null  float64
#  8   Bioenergy_MW                     47952 non-null  float64
#  9   Agriculture_Electricity_Use_GWh  43250 non-null  float64
#  10  Solar_Pumps_Installed            42331 non-null  float64
# ...

# %%
# Statistical overview of data distribution
agri_data.describe()
# Out:
#                Year         Month  Renewable_Capacity_MW      Solar_MW  \
# count  47952.000000  47952.000000           45042.000000  44007.000000
# mean    2019.978416      6.491012            1637.591103    896.401154
# std        3.167492      3.454680            1488.414163    824.736425
# min     2015.000000      1.000000              49.024485     22.259564
# 25%     2017.000000      3.000000             429.442242    231.663081
# 50%     2020.000000      6.000000            1137.963397    613.478180
# 75%     2023.000000      9.000000            2618.843989   1420.875358
# max     2025.000000     12.000000            6906.781898   4275.366352
#
#             Wind_MW      Hydro_MW  Bioenergy_MW  \
# count  44692.000000  47952.000000  47952.000000
# mean     369.886952    163.179841     89.949419
# std      348.801263    161.285320     88.156848
# min        7.645911      2.533761      1.574840
# 25%       91.607303     38.237684     21.293676
# ...

# %%
# Null value overview
agri_data.isna().sum()
# Out:
# State                                 0
# District                              0
# Year                                  0
# Month                                 0
# Renewable_Capacity_MW              2910
# Solar_MW                           3945
# Wind_MW                            3260
# Hydro_MW                              0
# Bioenergy_MW                          0
# Agriculture_Electricity_Use_GWh    4702
# Solar_Pumps_Installed              5621
# Estimated_CO2_Reduction_tonnes        0
# dtype: int64

# %%
(agri_data.isna().mean()*100).round(2)
# Out:
# State                               0.00
# District                            0.00
# Year                                0.00
# Month                               0.00
# Renewable_Capacity_MW               6.07
# Solar_MW                            8.23
# Wind_MW                             6.80
# Hydro_MW                            0.00
# Bioenergy_MW                        0.00
# Agriculture_Electricity_Use_GWh     9.81
# Solar_Pumps_Installed              11.72
# Estimated_CO2_Reduction_tonnes      0.00
# dtype: float64

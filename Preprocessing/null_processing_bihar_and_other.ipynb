# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('agri_energy_merged.csv')

# %%
df.isna().sum()
# Out:
# Unnamed: 0.1                          0
# Unnamed: 0                            0
# state                                 0
# district                              0
# year                                  0
# month                                 0
# solar_mw_district                 23892
# wind_mw                           50028
# bioenergy_mw                       4356
# solar_pumps_installed             10824
# estimated_co2_reduction_tonnes    23892
# dtype: int64

# %%
# Group by state & district and count nulls column-wise
null_summary = (
    df
    .groupby(['state', 'district'], as_index=False)
    .agg(lambda x: x.isna().sum())
)

# Keep only rows where at least one null exists
null_summary_filtered = null_summary[
    null_summary.drop(columns=['state', 'district']).sum(axis=1) > 0
]

null_summary_filtered.loc[1:20]
# Out:
#              state                     district  Unnamed: 0.1  Unnamed: 0  \
# 3   andhra pradesh                     adilabad             0           0
# 4   andhra pradesh                    anantapur             0           0
# 5   andhra pradesh                     chittoor             0           0
# 6   andhra pradesh                east godavari             0           0
# 7   andhra pradesh                       guntur             0           0
# 8   andhra pradesh                    hyderabad             0           0
# 9   andhra pradesh                   karimnagar             0           0
# 10  andhra pradesh                      khammam             0           0
# 11  andhra pradesh                      krishna             0           0
# 12  andhra pradesh                      kurnool             0           0
# 13  andhra pradesh                  mahbubnagar             0           0
# 14  andhra pradesh                        medak             0           0
# 15  andhra pradesh                     nalgonda             0           0
# 16  andhra pradesh                    nizamabad             0           0
# 17  andhra pradesh                     prakasam             0           0
# 18  andhra pradesh                   rangareddy             0           0
# 19  andhra pradesh  sri potti sriramulu nellore             0           0
# 20  andhra pradesh                   srikakulam             0           0
#
#     year  month  solar_mw_district  wind_mw  bioenergy_mw  \
# 3      0      0                  0        0             0
# 4      0      0                  0        0             0
# 5      0      0                  0        0             0
# 6      0      0                  0        0             0
# 7      0      0                  0        0             0
# 8      0      0                  0        0             0
# 9      0      0                  0        0             0
# 10     0      0                  0        0             0
# 11     0      0                  0        0             0
# 12     0      0                  0        0             0
# 13     0      0                  0        0             0
# 14     0      0                  0        0             0
# 15     0      0                  0        0             0
# 16     0      0                  0        0             0
# 17     0      0                  0        0             0
# 18     0      0                  0        0             0
# 19     0      0                  0        0             0
# 20     0      0                  0        0             0
#
#     solar_pumps_installed  estimated_co2_reduction_tonnes
# 3                     132                               0
# 4                     132                               0
# 5                     132                               0
# 6                     132                               0
# 7                     132                               0
# 8                     132                               0
# 9                     132                               0
# 10                    132                               0
# 11                    132                               0
# 12                    132                               0
# 13                    132                               0
# 14                    132                               0
# 15                    132                               0
# 16                    132                               0
# 17                    132                               0
# 18                    132                               0
# 19                    132                               0
# 20                    132                               0

# %%
ap_pumps_2019 = {
    'Vizianagaram': 4225,
    'East Godavari': 3256,
    'Krishna': 2584,
    'Visakhapatnam': 2516,
    'Srikakulam': 1697,
    'West Godavari': 1357
}

# %%
rows = []

for district, total_pumps in ap_pumps_2019.items():
    monthly_add = total_pumps / n_months

    cumulative = 0
    for date in monthly_range_phase1:
        cumulative += monthly_add
        rows.append({
            'state': 'Andhra Pradesh',
            'district': district,
            'date': date,
            'year': date.year,
            'month': date.month,
            'solar_pumps_installed': round(cumulative),
        })

phase1_df = pd.DataFrame(rows)
phase1_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       1 rows = []
#       3 for district, total_pumps in ap_pumps_2019.items():
# ----> 4     monthly_add = total_pumps / n_months
#       6     cumulative = 0
#       7     for date in monthly_range_phase1:
#
# NameError: name 'n_months' is not defined

# %%
PUMP_KW = 3.7

phase1_df['solar_mw_district'] = (
    phase1_df['solar_pumps_installed'] * PUMP_KW / 1000
)

# %%
rows = []

for district in ap_pumps_2019.keys():
    cumulative_mw = phase1_df[
        phase1_df['district'] == district
    ]['solar_mw_district'].max()

    for date in monthly_range_phase2:
        cumulative_mw += monthly_mw_add

        rows.append({
            'state': 'Andhra Pradesh',
            'district': district,
            'date': date,
            'year': date.year,
            'month': date.month,
            'solar_pumps_installed': ap_pumps_2019[district],  # fixed after 2019
            'solar_mw_district': round(cumulative_mw, 2)
        })

phase2_df = pd.DataFrame(rows)

# %%
ap_monthly_df = pd.concat([phase1_df, phase2_df], ignore_index=True)
ap_monthly_df.sort_values(['district']).head(15)

# %%
ap_monthly_df['wind_mw'] = 0.0
ap_monthly_df['bioenergy_mw'] = 0.0

# %%
EMISSION_FACTOR = 0.82  # kg CO2 / kWh

ap_monthly_df['estimated_co2_reduction_tonnes'] = (
    ap_monthly_df['solar_mw_district'] *
    1000 *  # MW → kW
    30 *  # avg days per month
    4.2 * # avg kWh/kWp/day (AP average)
    EMISSION_FACTOR / 1000
).round(2)

# %%
df = pd.concat([df, ap_monthly_df], ignore_index=True)

# %%
df.shape

# %%
# Group by state & district and count nulls column-wise
null_summary = (
    df
    .groupby(['state', 'district'], as_index=False)
    .agg(lambda x: x.isna().sum())
)

# Keep only rows where at least one null exists
null_summary_filtered = null_summary[
    null_summary.drop(columns=['state', 'district']).sum(axis=1) > 0
]

null_summary_filtered.loc[0:20]

# %%
df.columns

# %%
df= df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)

# %%
df = df.drop(['date'], axis=1)

# %%
df.columns

# %%
df.isna().sum()

# %%
# Group by state & district and count nulls column-wise
null_summary = (
    df
    .groupby(['state', 'district'], as_index=False)
    .agg(lambda x: x.isna().sum())
)

# Keep only rows where at least one null exists
null_summary_filtered = null_summary[
    null_summary.drop(columns=['state', 'district']).sum(axis=1) > 0
]

null_summary_filtered.loc[20:40]

# %%
ap_pump_targets = {
    'east godavari': 3256,
    'krishna': 2584,
    'vizianagaram': 4225,
    'visakhapatnam': 2516,
    'srikakulam': 1697,
    'west godavari': 1357
}

# %%
pump_growth_ratio = {
    2015: 0.05,
    2016: 0.20,
    2017: 0.45,
    2018: 0.75,
    2019: 1.00,
    2020: 1.00,
    2021: 1.00,
    2022: 1.00,
    2023: 1.00,
    2024: 1.00,
    2025: 1.00
}

# %%
def get_target_pumps(row):
    d = row['district'].lower()
    y = row['year']

    # if district data available
    if d in ap_pump_targets:
        final_pumps = ap_pump_targets[d]
    else:
        final_pumps = 132   # fallback average from your table

    ratio = pump_growth_ratio.get(y, 1.0)
    return round(final_pumps * ratio)

# %%
mask_ap = df['state'].str.lower().eq('andhra pradesh')

df.loc[mask_ap, 'solar_pumps_installed'] = (
    df.loc[mask_ap].apply(get_target_pumps, axis=1)
)
mask_ap.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 4>()
#       1 mask_ap = df['state'].str.lower().eq('andhra pradesh')
#       3 df.loc[mask_ap, 'solar_pumps_installed'] = (
# ----> 4     df.loc[mask_ap].apply(get_target_pumps, axis=1)
#       5 )
#       6 mask_ap.sum()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# Input In [8], in get_target_pumps(row)
#       3 y = row['year']
#       5 # if district data available
# ----> 6 if d in ap_pump_targets:
#       7     final_pumps = ap_pump_targets[d]
#       8 else:
#
# NameError: name 'ap_pump_targets' is not defined

# %%
PUMP_KW = 3.7

df.loc[mask_ap, 'solar_mw_district'] = (
    df.loc[mask_ap, 'solar_pumps_installed'] * PUMP_KW / 1000
).round(3)

# %%
feeder_mw_add = {
    2020: 10,
    2021: 20,
    2022: 40,
    2023: 80,
    2024: 120,
    2025: 150
}

# %%
ap_district_count = df[mask_ap]['district'].nunique()

def add_feeder_mw(row):
    y = row['year']
    add = feeder_mw_add.get(y, 0)
    return add / ap_district_count

# %%
df.loc[mask_ap, 'solar_mw_district'] += (
    df.loc[mask_ap].apply(add_feeder_mw, axis=1)
)

# %%
EMISSION_FACTOR = 0.82
AVG_KWH_PER_KWP = 4.2

df.loc[mask_ap, 'estimated_co2_reduction_tonnes'] = (
    df.loc[mask_ap, 'solar_mw_district'] *
    1000 * 30 * AVG_KWH_PER_KWP *
    EMISSION_FACTOR / 1000
).round(2)

# %%
df.isna().sum()
# Out:
# Unnamed: 0.1                          0
# Unnamed: 0                            0
# state                                 0
# district                              0
# year                                  0
# month                                 0
# solar_mw_district                 23892
# wind_mw                           50028
# bioenergy_mw                       4356
# solar_pumps_installed             10824
# estimated_co2_reduction_tonnes    23892
# dtype: int64

# %%
# 1. Solar pumps
df.loc[mask_ap, 'solar_pumps_installed'] = df.loc[mask_ap].apply(get_target_pumps, axis=1)

# 2. Solar MW
df.loc[mask_ap, 'solar_mw_district'] = (
    df.loc[mask_ap, 'solar_pumps_installed'] * PUMP_KW / 1000
)

# 3. Add feeder MW (2020–2025)
df.loc[mask_ap, 'solar_mw_district'] += df.loc[mask_ap].apply(add_feeder_mw, axis=1)

# 4. CO2 reduction
df.loc[mask_ap, 'estimated_co2_reduction_tonnes'] = (
    df.loc[mask_ap, 'solar_mw_district'] *
    1000 * 30 * AVG_KWH_PER_KWP *
    EMISSION_FACTOR / 1000
).round(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 # 1. Solar pumps
# ----> 2 df.loc[mask_ap, 'solar_pumps_installed'] = df.loc[mask_ap].apply(get_target_pumps, axis=1)
#       4 # 2. Solar MW
#       5 df.loc[mask_ap, 'solar_mw_district'] = (
#       6     df.loc[mask_ap, 'solar_pumps_installed'] * PUMP_KW / 1000
#       7 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# Input In [8], in get_target_pumps(row)
#       3 y = row['year']
#       5 # if district data available
# ----> 6 if d in ap_pump_targets:
#       7     final_pumps = ap_pump_targets[d]
#       8 else:
#
# NameError: name 'ap_pump_targets' is not defined

# %%
df.to_csv('ari_energy_filled.csv', index=False)

# %%
df.isna().sum()
# Out:
# Unnamed: 0.1                          0
# Unnamed: 0                            0
# state                                 0
# district                              0
# year                                  0
# month                                 0
# solar_mw_district                 23892
# wind_mw                           50028
# bioenergy_mw                       4356
# solar_pumps_installed             10824
# estimated_co2_reduction_tonnes    23892
# dtype: int64

# %%
# Group by state & district and count nulls column-wise
null_summary = (
    df
    .groupby(['state', 'district'], as_index=False)
    .agg(lambda x: x.isna().sum())
)

# Keep only rows where at least one null exists
null_summary_filtered = null_summary[
    null_summary.drop(columns=['state', 'district']).sum(axis=1) > 0
]

null_summary_filtered[45:70]
# Out:
#     state         district  Unnamed: 0.1  Unnamed: 0  year  month  \
# 64  assam          nalbari             0           0     0      0
# 65  assam        sivasagar             0           0     0      0
# 66  assam         sonitpur             0           0     0      0
# 67  assam         tinsukia             0           0     0      0
# 68  assam         udalguri             0           0     0      0
# 69  bihar           araria             0           0     0      0
# 70  bihar            arwal             0           0     0      0
# 71  bihar       aurangabad             0           0     0      0
# 72  bihar            banka             0           0     0      0
# 73  bihar        begusarai             0           0     0      0
# 74  bihar        bhagalpur             0           0     0      0
# 75  bihar          bhojpur             0           0     0      0
# 76  bihar            buxar             0           0     0      0
# 77  bihar        darbhanga             0           0     0      0
# 78  bihar             gaya             0           0     0      0
# 79  bihar        gopalganj             0           0     0      0
# 80  bihar            jamui             0           0     0      0
# 81  bihar        jehanabad             0           0     0      0
# 82  bihar  kaimur (bhabua)             0           0     0      0
# 83  bihar          katihar             0           0     0      0
# 84  bihar         khagaria             0           0     0      0
# 85  bihar       kishanganj             0           0     0      0
# 86  bihar       lakhisarai             0           0     0      0
# 87  bihar        madhepura             0           0     0      0
# 88  bihar        madhubani             0           0     0      0
#
#     solar_mw_district  wind_mw  bioenergy_mw  solar_pumps_installed  \
# 64                132      132             0                      0
# 65                132      132             0                      0
# 66                132      132             0                      0
# 67                132      132             0                      0
# 68                132      132             0                      0
# 69                132      132             0                      0
# 70                132      132             0                      0
# 71                132      132             0                      0
# 72                132      132             0                      0
# 73                132      132             0                      0
# 74                132      132             0                      0
# 75                132      132             0                      0
# 76                132      132             0                      0
# 77                132      132             0                      0
# 78                132      132             0                      0
# 79                132      132             0                      0
# 80                132      132             0                      0
# 81                132      132             0                      0
# 82                132      132             0                      0
# 83                132      132             0                      0
# 84                132      132             0                      0
# 85                132      132             0                      0
# 86                132      132             0                      0
# 87                132      132             0                      0
# 88                132      132             0                      0
#
#     estimated_co2_reduction_tonnes
# 64                             132
# 65                             132
# 66                             132
# 67                             132
# 68                             132
# 69                             132
# 70                             132
# 71                             132
# 72                             132
# 73                             132
# 74                             132
# 75                             132
# 76                             132
# 77                             132
# 78                             132
# 79                             132
# 80                             132
# 81                             132
# 82                             132
# 83                             132
# 84                             132
# 85                             132
# 86                             132
# 87                             132
# 88                             132

# %%
# Assam: PM-KUSUM Solar Pumps (Component-B)
assam_pumps_yearly = {
    2015: 0,
    2016: 50,
    2017: 100,
    2018: 200,
    2019: 300,
    2020: 500,
    2021: 800,
    2022: 1200,
    2023: 2000,
    2024: 3000,
    2025: 4000
}

# Bihar: Solar MW (Standalone + FLS)
bihar_solar_standalone_yearly = {
    2015: 0,
    2016: 10,
    2017: 25,
    2018: 50,
    2019: 80,
    2020: 100,
    2021: 120,
    2022: 140,
    2023: 150,
    2024: 165,
    2025: 180
}

bihar_agri_pv_yearly = {
    2015: 0,
    2016: 20,
    2017: 50,
    2018: 100,
    2019: 150,
    2020: 200,
    2021: 250,
    2022: 280,
    2023: 320,
    2024: 355,
    2025: 390
}

# Bioenergy (MW) approximate
assam_bio_mw = 1.2  # small scale tea/biogas
bihar_bio_mw = 3.4  # rice husk/biomass projects

# Wind MW approximate
assam_wind_mw = 0
bihar_wind_mw = 0.05

# %%
def fill_assam_bihar(row):
    state = row['state'].lower()
    year = row['year']
    
    # Assam
    if state == 'assam':
        row['solar_pumps_installed'] = assam_pumps_yearly.get(year, 0)
        row['solar_mw_district'] = round(row['solar_pumps_installed'] * 0.75 / 1000, 3)  # 0.75 kW per pump
        row['bioenergy_mw'] = assam_bio_mw
        row['wind_mw'] = assam_wind_mw
        # CO2 reduction estimate: assume 1 kWh per kWp per day * 30 days * 0.82 kg CO2/kWh
        row['estimated_co2_reduction_tonnes'] = round(row['solar_mw_district'] * 1000 * 4 * 30 * 0.82 / 1000, 2)
        
    # Bihar
    elif state == 'bihar':
        # Sum of standalone + Agri-PV
        solar_total_mw = bihar_solar_standalone_yearly.get(year, 0) + bihar_agri_pv_yearly.get(year, 0)
        row['solar_mw_district'] = solar_total_mw
        row['solar_pumps_installed'] = int(bihar_solar_standalone_yearly.get(year, 0) * 1000 / 0.75)  # convert MW to # pumps approx
        row['bioenergy_mw'] = bihar_bio_mw
        row['wind_mw'] = bihar_wind_mw
        # CO2 reduction
        row['estimated_co2_reduction_tonnes'] = round(row['solar_mw_district'] * 1000 * 4 * 30 * 0.82 / 1000, 2)
    
    return row

df= df.apply(fill_assam_bihar, axis=1)

# %%
# Group by state & district and count nulls column-wise
null_summary = (
    df
    .groupby(['state', 'district'], as_index=False)
    .agg(lambda x: x.isna().sum())
)

# Keep only rows where at least one null exists
null_summary_filtered = null_summary[
    null_summary.drop(columns=['state', 'district']).sum(axis=1) > 0
]

null_summary_filtered[45:70]
# Out:
#                 state      district  Unnamed: 0.1  Unnamed: 0  year  month  \
# 129               goa     north goa             0           0     0      0
# 130               goa     south goa             0           0     0      0
# 157           haryana        ambala             0           0     0      0
# 158           haryana       bhiwani             0           0     0      0
# 159           haryana     faridabad             0           0     0      0
# 160           haryana     fatehabad             0           0     0      0
# 161           haryana       gurgaon             0           0     0      0
# 162           haryana         hisar             0           0     0      0
# 163           haryana       jhajjar             0           0     0      0
# 164           haryana          jind             0           0     0      0
# 165           haryana       kaithal             0           0     0      0
# 166           haryana        karnal             0           0     0      0
# 167           haryana   kurukshetra             0           0     0      0
# 168           haryana  mahendragarh             0           0     0      0
# 169           haryana         mewat             0           0     0      0
# 170           haryana        palwal             0           0     0      0
# 171           haryana     panchkula             0           0     0      0
# 172           haryana       panipat             0           0     0      0
# 173           haryana        rewari             0           0     0      0
# 174           haryana        rohtak             0           0     0      0
# 175           haryana         sirsa             0           0     0      0
# 176           haryana       sonipat             0           0     0      0
# 177           haryana   yamunanagar             0           0     0      0
# 178  himachal pradesh      bilaspur             0           0     0      0
# 179  himachal pradesh        chamba             0           0     0      0
#
#      solar_mw_district  wind_mw  bioenergy_mw  solar_pumps_installed  \
# 129                132      132             0                      0
# 130                132      132             0                      0
# 157                  0      132             0                      0
# 158                  0      132             0                      0
# 159                  0      132             0                      0
# 160                  0      132             0                      0
# 161                  0      132             0                      0
# 162                  0      132             0                      0
# 163                  0      132             0                      0
# 164                  0      132             0                      0
# 165                  0      132             0                      0
# 166                  0      132             0                      0
# 167                  0      132             0                      0
# 168                  0      132             0                      0
# 169                  0      132             0                      0
# 170                  0      132             0                      0
# 171                  0      132             0                      0
# 172                  0      132             0                      0
# 173                  0      132             0                      0
# 174                  0      132             0                      0
# 175                  0      132             0                      0
# 176                  0      132             0                      0
# 177                  0      132             0                      0
# 178                132      132             0                      0
# 179                132      132             0                      0
#
#      estimated_co2_reduction_tonnes
# 129                             132
# 130                             132
# 157                               0
# 158                               0
# 159                               0
# 160                               0
# 161                               0
# 162                               0
# 163                               0
# 164                               0
# 165                               0
# 166                               0
# 167                               0
# 168                               0
# 169                               0
# 170                               0
# 171                               0
# 172                               0
# 173                               0
# 174                               0
# 175                               0
# 176                               0
# 177                               0
# 178                             132
# 179                             132

# %%
df.isna().sum()
# Out:
# Unnamed: 0.1                          0
# Unnamed: 0                            0
# state                                 0
# district                              0
# year                                  0
# month                                 0
# solar_mw_district                 15312
# wind_mw                           41448
# bioenergy_mw                       4356
# solar_pumps_installed             10824
# estimated_co2_reduction_tonnes    15312
# dtype: int64

# %%
df.to_csv('agri_energy_merged.csv', index=False)

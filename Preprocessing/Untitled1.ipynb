# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('agri_energy_merged.csv')

# %%
df.isna().sum()
# Out:
# Unnamed: 0.1                          0
# Unnamed: 0                            0
# state                                 0
# district                              0
# year                                  0
# month                                 0
# solar_mw_district                 23892
# wind_mw                           50028
# bioenergy_mw                       4356
# solar_pumps_installed             10824
# estimated_co2_reduction_tonnes    23892
# dtype: int64

# %%
# Group by state & district and count nulls column-wise
null_summary = (
    df
    .groupby(['state', 'district'], as_index=False)
    .agg(lambda x: x.isna().sum())
)

# Keep only rows where at least one null exists
null_summary_filtered = null_summary[
    null_summary.drop(columns=['state', 'district']).sum(axis=1) > 0
]

null_summary_filtered.loc[1:20]
# Out:
#              state                     district  Unnamed: 0.1  Unnamed: 0  \
# 3   andhra pradesh                     adilabad             0           0
# 4   andhra pradesh                    anantapur             0           0
# 5   andhra pradesh                     chittoor             0           0
# 6   andhra pradesh                east godavari             0           0
# 7   andhra pradesh                       guntur             0           0
# 8   andhra pradesh                    hyderabad             0           0
# 9   andhra pradesh                   karimnagar             0           0
# 10  andhra pradesh                      khammam             0           0
# 11  andhra pradesh                      krishna             0           0
# 12  andhra pradesh                      kurnool             0           0
# 13  andhra pradesh                  mahbubnagar             0           0
# 14  andhra pradesh                        medak             0           0
# 15  andhra pradesh                     nalgonda             0           0
# 16  andhra pradesh                    nizamabad             0           0
# 17  andhra pradesh                     prakasam             0           0
# 18  andhra pradesh                   rangareddy             0           0
# 19  andhra pradesh  sri potti sriramulu nellore             0           0
# 20  andhra pradesh                   srikakulam             0           0
#
#     year  month  solar_mw_district  wind_mw  bioenergy_mw  \
# 3      0      0                  0        0             0
# 4      0      0                  0        0             0
# 5      0      0                  0        0             0
# 6      0      0                  0        0             0
# 7      0      0                  0        0             0
# 8      0      0                  0        0             0
# 9      0      0                  0        0             0
# 10     0      0                  0        0             0
# 11     0      0                  0        0             0
# 12     0      0                  0        0             0
# 13     0      0                  0        0             0
# 14     0      0                  0        0             0
# 15     0      0                  0        0             0
# 16     0      0                  0        0             0
# 17     0      0                  0        0             0
# 18     0      0                  0        0             0
# 19     0      0                  0        0             0
# 20     0      0                  0        0             0
#
#     solar_pumps_installed  estimated_co2_reduction_tonnes
# 3                     132                               0
# 4                     132                               0
# 5                     132                               0
# 6                     132                               0
# 7                     132                               0
# 8                     132                               0
# 9                     132                               0
# 10                    132                               0
# 11                    132                               0
# 12                    132                               0
# 13                    132                               0
# 14                    132                               0
# 15                    132                               0
# 16                    132                               0
# 17                    132                               0
# 18                    132                               0
# 19                    132                               0
# 20                    132                               0

# %%
ap_pumps_2019 = {
    'Vizianagaram': 4225,
    'East Godavari': 3256,
    'Krishna': 2584,
    'Visakhapatnam': 2516,
    'Srikakulam': 1697,
    'West Godavari': 1357
}

# %%
rows = []

for district, total_pumps in ap_pumps_2019.items():
    monthly_add = total_pumps / n_months

    cumulative = 0
    for date in monthly_range_phase1:
        cumulative += monthly_add
        rows.append({
            'state': 'Andhra Pradesh',
            'district': district,
            'date': date,
            'year': date.year,
            'month': date.month,
            'solar_pumps_installed': round(cumulative),
        })

phase1_df = pd.DataFrame(rows)
phase1_df.head()
# Out:
#             state      district       date  year  month  solar_pumps_installed
# 0  Andhra Pradesh  Vizianagaram 2016-04-01  2016      4                    103
# 1  Andhra Pradesh  Vizianagaram 2016-05-01  2016      5                    206
# 2  Andhra Pradesh  Vizianagaram 2016-06-01  2016      6                    309
# 3  Andhra Pradesh  Vizianagaram 2016-07-01  2016      7                    412
# 4  Andhra Pradesh  Vizianagaram 2016-08-01  2016      8                    515

# %%
PUMP_KW = 3.7

phase1_df['solar_mw_district'] = (
    phase1_df['solar_pumps_installed'] * PUMP_KW / 1000
)

# %%
rows = []

for district in ap_pumps_2019.keys():
    cumulative_mw = phase1_df[
        phase1_df['district'] == district
    ]['solar_mw_district'].max()

    for date in monthly_range_phase2:
        cumulative_mw += monthly_mw_add

        rows.append({
            'state': 'Andhra Pradesh',
            'district': district,
            'date': date,
            'year': date.year,
            'month': date.month,
            'solar_pumps_installed': ap_pumps_2019[district],  # fixed after 2019
            'solar_mw_district': round(cumulative_mw, 2)
        })

phase2_df = pd.DataFrame(rows)

# %%
ap_monthly_df = pd.concat([phase1_df, phase2_df], ignore_index=True)
ap_monthly_df.sort_values(['district']).head(15)
# Out:
#               state       district       date  year  month  \
# 350  Andhra Pradesh  East Godavari 2022-01-01  2022      1
# 364  Andhra Pradesh  East Godavari 2023-03-01  2023      3
# 363  Andhra Pradesh  East Godavari 2023-02-01  2023      2
# 362  Andhra Pradesh  East Godavari 2023-01-01  2023      1
# 361  Andhra Pradesh  East Godavari 2022-12-01  2022     12
# 360  Andhra Pradesh  East Godavari 2022-11-01  2022     11
# 359  Andhra Pradesh  East Godavari 2022-10-01  2022     10
# 358  Andhra Pradesh  East Godavari 2022-09-01  2022      9
# 81   Andhra Pradesh  East Godavari 2019-08-01  2019      8
# 80   Andhra Pradesh  East Godavari 2019-07-01  2019      7
# 79   Andhra Pradesh  East Godavari 2019-06-01  2019      6
# 78   Andhra Pradesh  East Godavari 2019-05-01  2019      5
# 77   Andhra Pradesh  East Godavari 2019-04-01  2019      4
# 365  Andhra Pradesh  East Godavari 2023-04-01  2023      4
# 76   Andhra Pradesh  East Godavari 2019-03-01  2019      3
#
#      solar_pumps_installed  solar_mw_district
# 350                   3256           202.8400
# 364                   3256           294.9400
# 363                   3256           288.3600
# 362                   3256           281.7800
# 361                   3256           275.2100
# 360                   3256           268.6300
# 359                   3256           262.0500
# 358                   3256           255.4700
# 81                    3256            12.0472
# 80                    3177            11.7549
# 79                    3097            11.4589
# 78                    3018            11.1666
# 77                    2938            10.8706
# 365                   3256           301.5200
# 76                    2859            10.5783

# %%
ap_monthly_df['wind_mw'] = 0.0
ap_monthly_df['bioenergy_mw'] = 0.0

# %%
EMISSION_FACTOR = 0.82  # kg CO2 / kWh

ap_monthly_df['estimated_co2_reduction_tonnes'] = (
    ap_monthly_df['solar_mw_district'] *
    1000 *  # MW → kW
    30 *  # avg days per month
    4.2 * # avg kWh/kWp/day (AP average)
    EMISSION_FACTOR / 1000
).round(2)

# %%
df = pd.concat([df, ap_monthly_df], ignore_index=True)

# %%
df.shape
# Out:
# (85314, 12)

# %%
# Group by state & district and count nulls column-wise
null_summary = (
    df
    .groupby(['state', 'district'], as_index=False)
    .agg(lambda x: x.isna().sum())
)

# Keep only rows where at least one null exists
null_summary_filtered = null_summary[
    null_summary.drop(columns=['state', 'district']).sum(axis=1) > 0
]

null_summary_filtered.loc[0:20]
# Out:
#                        state                district  Unnamed: 0.1  \
# 0             Andhra Pradesh           East Godavari           117
# 1             Andhra Pradesh                 Krishna           117
# 2             Andhra Pradesh              Srikakulam           117
# 3             Andhra Pradesh           Visakhapatnam           117
# 4             Andhra Pradesh            Vizianagaram           117
# 5             Andhra Pradesh           West Godavari           117
# 6   andaman & nicobar island                 nicobar             0
# 7   andaman & nicobar island  north & middle andaman             0
# 8   andaman & nicobar island           south andaman             0
# 9             andhra pradesh                adilabad             0
# 10            andhra pradesh               anantapur             0
# 11            andhra pradesh                chittoor             0
# 12            andhra pradesh           east godavari             0
# 13            andhra pradesh                  guntur             0
# 14            andhra pradesh               hyderabad             0
# 15            andhra pradesh              karimnagar             0
# 16            andhra pradesh                 khammam             0
# 17            andhra pradesh                 krishna             0
# 18            andhra pradesh                 kurnool             0
# 19            andhra pradesh             mahbubnagar             0
# 20            andhra pradesh                   medak             0
#
#     Unnamed: 0  year  month  solar_mw_district  wind_mw  bioenergy_mw  \
# 0          117     0      0                  0        0             0
# 1          117     0      0                  0        0             0
# 2          117     0      0                  0        0             0
# 3          117     0      0                  0        0             0
# 4          117     0      0                  0        0             0
# 5          117     0      0                  0        0             0
# 6            0     0      0                  0        0             0
# 7            0     0      0                  0        0             0
# 8            0     0      0                  0        0             0
# 9            0     0      0                  0        0             0
# 10           0     0      0                  0        0             0
# 11           0     0      0                  0        0             0
# 12           0     0      0                  0        0             0
# 13           0     0      0                  0        0             0
# 14           0     0      0                  0        0             0
# 15           0     0      0                  0        0             0
# 16           0     0      0                  0        0             0
# 17           0     0      0                  0        0             0
# 18           0     0      0                  0        0             0
# 19           0     0      0                  0        0             0
# 20           0     0      0                  0        0             0
#
#     solar_pumps_installed  estimated_co2_reduction_tonnes  date
# 0                       0                               0     0
# 1                       0                               0     0
# 2                       0                               0     0
# 3                       0                               0     0
# 4                       0                               0     0
# 5                       0                               0     0
# 6                       0                               0   132
# 7                       0                               0   132
# 8                       0                               0   132
# 9                     132                               0   132
# 10                    132                               0   132
# 11                    132                               0   132
# 12                    132                               0   132
# 13                    132                               0   132
# 14                    132                               0   132
# 15                    132                               0   132
# 16                    132                               0   132
# 17                    132                               0   132
# 18                    132                               0   132
# 19                    132                               0   132
# 20                    132                               0   132

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'state', 'district', 'year', 'month',
#        'solar_mw_district', 'wind_mw', 'bioenergy_mw', 'solar_pumps_installed',
#        'estimated_co2_reduction_tonnes', 'date'],
#       dtype='object')

# %%
df= df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)

# %%
df = df.drop(['date'], axis=1)

# %%
df.columns
# Out:
# Index(['state', 'district', 'year', 'month', 'solar_mw_district', 'wind_mw',
#        'bioenergy_mw', 'solar_pumps_installed',
#        'estimated_co2_reduction_tonnes'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# state                                 0
# district                              0
# year                                  0
# month                                 0
# solar_mw_district                 23892
# wind_mw                           50028
# bioenergy_mw                       4356
# solar_pumps_installed             10824
# estimated_co2_reduction_tonnes    23892
# dtype: int64

# %%
# Group by state & district and count nulls column-wise
null_summary = (
    df
    .groupby(['state', 'district'], as_index=False)
    .agg(lambda x: x.isna().sum())
)

# Keep only rows where at least one null exists
null_summary_filtered = null_summary[
    null_summary.drop(columns=['state', 'district']).sum(axis=1) > 0
]

null_summary_filtered.loc[20:40]
# Out:
# Empty DataFrame
# Columns: [state, district, year, month, solar_mw_district, wind_mw, bioenergy_mw, solar_pumps_installed, estimated_co2_reduction_tonnes]
# Index: []

# %%
ap_pump_targets = {
    'east godavari': 3256,
    'krishna': 2584,
    'vizianagaram': 4225,
    'visakhapatnam': 2516,
    'srikakulam': 1697,
    'west godavari': 1357
}

# %%
pump_growth_ratio = {
    2015: 0.05,
    2016: 0.20,
    2017: 0.45,
    2018: 0.75,
    2019: 1.00,
    2020: 1.00,
    2021: 1.00,
    2022: 1.00,
    2023: 1.00,
    2024: 1.00,
    2025: 1.00
}

# %%
def get_target_pumps(row):
    d = row['district'].lower()
    y = row['year']

    # if district data available
    if d in ap_pump_targets:
        final_pumps = ap_pump_targets[d]
    else:
        final_pumps = 132   # fallback average from your table

    ratio = pump_growth_ratio.get(y, 1.0)
    return round(final_pumps * ratio)

# %%
mask_ap = df['state'].str.lower().eq('andhra pradesh')

df.loc[mask_ap, 'solar_pumps_installed'] = (
    df.loc[mask_ap].apply(get_target_pumps, axis=1)
)
mask_ap.sum()
# Out:
# np.int64(3738)

# %%
PUMP_KW = 3.7

df.loc[mask_ap, 'solar_mw_district'] = (
    df.loc[mask_ap, 'solar_pumps_installed'] * PUMP_KW / 1000
).round(3)

# %%
feeder_mw_add = {
    2020: 10,
    2021: 20,
    2022: 40,
    2023: 80,
    2024: 120,
    2025: 150
}

# %%
ap_district_count = df[mask_ap]['district'].nunique()

def add_feeder_mw(row):
    y = row['year']
    add = feeder_mw_add.get(y, 0)
    return add / ap_district_count

# %%
df.loc[mask_ap, 'solar_mw_district'] += (
    df.loc[mask_ap].apply(add_feeder_mw, axis=1)
)

# %%
EMISSION_FACTOR = 0.82
AVG_KWH_PER_KWP = 4.2

df.loc[mask_ap, 'estimated_co2_reduction_tonnes'] = (
    df.loc[mask_ap, 'solar_mw_district'] *
    1000 * 30 * AVG_KWH_PER_KWP *
    EMISSION_FACTOR / 1000
).round(2)

# %%
df.isna().sum()
# Out:
# state                                 0
# district                              0
# year                                  0
# month                                 0
# solar_mw_district                 23892
# wind_mw                           50028
# bioenergy_mw                       4356
# solar_pumps_installed              7788
# estimated_co2_reduction_tonnes    23892
# dtype: int64

# %%
# 1. Solar pumps
df.loc[mask_ap, 'solar_pumps_installed'] = df.loc[mask_ap].apply(get_target_pumps, axis=1)

# 2. Solar MW
df.loc[mask_ap, 'solar_mw_district'] = (
    df.loc[mask_ap, 'solar_pumps_installed'] * PUMP_KW / 1000
)

# 3. Add feeder MW (2020–2025)
df.loc[mask_ap, 'solar_mw_district'] += df.loc[mask_ap].apply(add_feeder_mw, axis=1)

# 4. CO2 reduction
df.loc[mask_ap, 'estimated_co2_reduction_tonnes'] = (
    df.loc[mask_ap, 'solar_mw_district'] *
    1000 * 30 * AVG_KWH_PER_KWP *
    EMISSION_FACTOR / 1000
).round(2)

# %%
df.to_csv('ari_energy_filled.csv', index=False)

# %%
df.isna().sum()
# Out:
# state                                 0
# district                              0
# year                                  0
# month                                 0
# solar_mw_district                 23892
# wind_mw                           50028
# bioenergy_mw                       4356
# solar_pumps_installed              7788
# estimated_co2_reduction_tonnes    23892
# dtype: int64

# %%
# Group by state & district and count nulls column-wise
null_summary = (
    df
    .groupby(['state', 'district'], as_index=False)
    .agg(lambda x: x.isna().sum())
)

# Keep only rows where at least one null exists
null_summary_filtered = null_summary[
    null_summary.drop(columns=['state', 'district']).sum(axis=1) > 0
]

null_summary_filtered[45:70]
# Out:
#             state                  district  year  month  solar_mw_district  \
# 93          bihar                 madhepura     0      0                132
# 94          bihar                 madhubani     0      0                132
# 95          bihar                    munger     0      0                132
# 96          bihar               muzaffarpur     0      0                132
# 97          bihar                   nalanda     0      0                132
# 98          bihar                    nawada     0      0                132
# 99          bihar        pashchim champaran     0      0                132
# 100         bihar                     patna     0      0                132
# 101         bihar           purba champaran     0      0                132
# 102         bihar                    purnia     0      0                132
# 103         bihar                    rohtas     0      0                132
# 104         bihar                   saharsa     0      0                132
# 105         bihar                samastipur     0      0                132
# 106         bihar           saran (chhapra)     0      0                132
# 107         bihar                sheikhpura     0      0                132
# 108         bihar                   sheohar     0      0                132
# 109         bihar                 sitamarhi     0      0                132
# 110         bihar                     siwan     0      0                132
# 111         bihar                    supaul     0      0                132
# 112         bihar                  vaishali     0      0                132
# 113    chandigarh                chandigarh     0      0                132
# 114  chhattisgarh                    bastar     0      0                132
# 115  chhattisgarh                   bijapur     0      0                132
# 116  chhattisgarh                  bilaspur     0      0                132
# 117  chhattisgarh  dakshin bastar dantewada     0      0                132
#
#      wind_mw  bioenergy_mw  solar_pumps_installed  \
# 93       132             0                      0
# 94       132             0                      0
# 95       132             0                      0
# 96       132             0                      0
# 97       132             0                      0
# 98       132             0                      0
# 99       132             0                      0
# 100      132             0                      0
# 101      132             0                      0
# 102      132             0                      0
# 103      132             0                      0
# 104      132             0                      0
# 105      132             0                      0
# 106      132             0                      0
# 107      132             0                      0
# 108      132             0                      0
# 109      132             0                      0
# 110      132             0                      0
# 111      132             0                      0
# 112      132             0                      0
# 113      132             0                    132
# 114      132           132                    132
# 115      132           132                    132
# 116      132           132                    132
# 117      132           132                    132
#
#      estimated_co2_reduction_tonnes
# 93                              132
# 94                              132
# 95                              132
# 96                              132
# 97                              132
# 98                              132
# 99                              132
# 100                             132
# 101                             132
# 102                             132
# 103                             132
# 104                             132
# 105                             132
# 106                             132
# 107                             132
# 108                             132
# 109                             132
# 110                             132
# 111                             132
# 112                             132
# 113                             132
# 114                             132
# 115                             132
# 116                             132
# 117                             132

# %%
# Assam: PM-KUSUM Solar Pumps (Component-B)
assam_pumps_yearly = {
    2015: 0,
    2016: 50,
    2017: 100,
    2018: 200,
    2019: 300,
    2020: 500,
    2021: 800,
    2022: 1200,
    2023: 2000,
    2024: 3000,
    2025: 4000
}

# Bihar: Solar MW (Standalone + FLS)
bihar_solar_standalone_yearly = {
    2015: 0,
    2016: 10,
    2017: 25,
    2018: 50,
    2019: 80,
    2020: 100,
    2021: 120,
    2022: 140,
    2023: 150,
    2024: 165,
    2025: 180
}

bihar_agri_pv_yearly = {
    2015: 0,
    2016: 20,
    2017: 50,
    2018: 100,
    2019: 150,
    2020: 200,
    2021: 250,
    2022: 280,
    2023: 320,
    2024: 355,
    2025: 390
}

# Bioenergy (MW) approximate
assam_bio_mw = 1.2  # small scale tea/biogas
bihar_bio_mw = 3.4  # rice husk/biomass projects

# Wind MW approximate
assam_wind_mw = 0
bihar_wind_mw = 0.05

# %%
def fill_assam_bihar(row):
    state = row['state'].lower()
    year = row['year']
    
    # Assam
    if state == 'assam':
        row['solar_pumps_installed'] = assam_pumps_yearly.get(year, 0)
        row['solar_mw_district'] = round(row['solar_pumps_installed'] * 0.75 / 1000, 3)  # 0.75 kW per pump
        row['bioenergy_mw'] = assam_bio_mw
        row['wind_mw'] = assam_wind_mw
        # CO2 reduction estimate: assume 1 kWh per kWp per day * 30 days * 0.82 kg CO2/kWh
        row['estimated_co2_reduction_tonnes'] = round(row['solar_mw_district'] * 1000 * 4 * 30 * 0.82 / 1000, 2)
        
    # Bihar
    elif state == 'bihar':
        # Sum of standalone + Agri-PV
        solar_total_mw = bihar_solar_standalone_yearly.get(year, 0) + bihar_agri_pv_yearly.get(year, 0)
        row['solar_mw_district'] = solar_total_mw
        row['solar_pumps_installed'] = int(bihar_solar_standalone_yearly.get(year, 0) * 1000 / 0.75)  # convert MW to # pumps approx
        row['bioenergy_mw'] = bihar_bio_mw
        row['wind_mw'] = bihar_wind_mw
        # CO2 reduction
        row['estimated_co2_reduction_tonnes'] = round(row['solar_mw_district'] * 1000 * 4 * 30 * 0.82 / 1000, 2)
    
    return row

df= df.apply(fill_assam_bihar, axis=1)

# %%
# Group by state & district and count nulls column-wise
null_summary = (
    df
    .groupby(['state', 'district'], as_index=False)
    .agg(lambda x: x.isna().sum())
)

# Keep only rows where at least one null exists
null_summary_filtered = null_summary[
    null_summary.drop(columns=['state', 'district']).sum(axis=1) > 0
]

null_summary_filtered[45:70]
# Out:
#                 state            district  year  month  solar_mw_district  \
# 184  himachal pradesh            bilaspur     0      0                132
# 185  himachal pradesh              chamba     0      0                132
# 186  himachal pradesh            hamirpur     0      0                132
# 187  himachal pradesh              kangra     0      0                132
# 188  himachal pradesh             kinnaur     0      0                132
# 189  himachal pradesh               kullu     0      0                132
# 190  himachal pradesh       lahul & spiti     0      0                132
# 191  himachal pradesh               mandi     0      0                132
# 192  himachal pradesh              shimla     0      0                132
# 193  himachal pradesh             sirmaur     0      0                132
# 194  himachal pradesh               solan     0      0                132
# 195  himachal pradesh                 una     0      0                132
# 196   jammu & kashmir            anantnag     0      0                132
# 197   jammu & kashmir              badgam     0      0                132
# 198   jammu & kashmir           bandipore     0      0                132
# 199   jammu & kashmir            baramula     0      0                132
# 200   jammu & kashmir  data not available     0      0                132
# 201   jammu & kashmir                doda     0      0                132
# 202   jammu & kashmir           ganderbal     0      0                132
# 203   jammu & kashmir               jammu     0      0                132
# 204   jammu & kashmir              kargil     0      0                132
# 205   jammu & kashmir              kathua     0      0                132
# 206   jammu & kashmir            kishtwar     0      0                132
# 207   jammu & kashmir              kulgam     0      0                132
# 208   jammu & kashmir             kupwara     0      0                132
#
#      wind_mw  bioenergy_mw  solar_pumps_installed  \
# 184      132             0                      0
# 185      132             0                      0
# 186      132             0                      0
# 187      132             0                      0
# 188      132             0                      0
# 189      132             0                      0
# 190      132             0                      0
# 191      132             0                      0
# 192      132             0                      0
# 193      132             0                      0
# 194      132             0                      0
# 195      132             0                      0
# 196      132             0                    132
# 197      132             0                    132
# 198      132             0                    132
# 199      132             0                    132
# 200      132             0                    132
# 201      132             0                    132
# 202      132             0                    132
# 203      132             0                    132
# 204      132             0                    132
# 205      132             0                    132
# 206      132             0                    132
# 207      132             0                    132
# 208      132             0                    132
#
#      estimated_co2_reduction_tonnes
# 184                             132
# 185                             132
# 186                             132
# 187                             132
# 188                             132
# 189                             132
# 190                             132
# 191                             132
# 192                             132
# 193                             132
# 194                             132
# 195                             132
# 196                             132
# 197                             132
# 198                             132
# 199                             132
# 200                             132
# 201                             132
# 202                             132
# 203                             132
# 204                             132
# 205                             132
# 206                             132
# 207                             132
# 208                             132

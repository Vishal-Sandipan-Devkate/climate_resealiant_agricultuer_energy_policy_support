# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:/Users/ASUS/Downloads/FAOSTAT_data_en_1-2-2026.csv')

# %%
data.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code',
#        'Element', 'Item Code', 'Item', 'Year Code', 'Year', 'Source Code',
#        'Source', 'Unit', 'Value', 'Flag', 'Flag Description', 'Note'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Domain Code          object
# Domain               object
# Area Code (M49)       int64
# Area                 object
# Element Code          int64
# Element              object
# Item Code             int64
# Item                 object
# Year Code             int64
# Year                  int64
# Source Code           int64
# Source               object
# Unit                 object
# Value               float64
# Flag                 object
# Flag Description     object
# Note                float64
# dtype: object

# %%
data

# %%
data['Domain Code'].unique()
# Out:
# array(['GT'], dtype=object)

# %%
data['Domain'].unique()
# Out:
# array(['Emissions totals'], dtype=object)

# %%
data.drop(['Domain Code', 'Domain'], axis=1)
# Out:
#        Area Code (M49)                      Area  Element Code  \
# 0                    4               Afghanistan          7234
# 1                    4               Afghanistan          7236
# 2                    4               Afghanistan          7230
# 3                    4               Afghanistan        724313
# 4                    4               Afghanistan        723113
# ...                ...                       ...           ...
# 33983              840  United States of America          7230
# 33984              840  United States of America          7273
# 33985              840  United States of America        724413
# 33986              840  United States of America        724313
# 33987              840  United States of America        723113
#
#                                 Element  Item Code           Item  Year Code  \
# 0                Direct emissions (N2O)       5064  Crop Residues       1961
# ...

# %%
data['Area Code (M49)'].unique()
# Out:
# array([  4,  16, 159, 356, 524, 840], dtype=int64)

# %%
data['Area'].unique()
# Out:
# array(['Afghanistan', 'American Samoa', 'China', 'India', 'Nepal',
#        'United States of America'], dtype=object)

# %%
data['Element Code'].unique()
# Out:
# array([  7234,   7236,   7230, 724313, 723113,   7225, 724413,   7273,
#        717815], dtype=int64)

# %%
data['Element'].unique()
# Out:
# array(['Direct emissions (N2O)', 'Indirect emissions (N2O)',
#        'Emissions (N2O)', 'Emissions (CO2eq) from N2O (AR5)',
#        'Emissions (CO2eq) (AR5)', 'Emissions (CH4)',
#        'Emissions (CO2eq) from CH4 (AR5)', 'Emissions (CO2)',
#        'Emissions (CO2eq) from F-gases (AR5)'], dtype=object)
